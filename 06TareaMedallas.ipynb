# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\_NotebookAvanzada_II\Pandas\medallas.csv")
df
# Out:
#      Oro  Plata  Bronce  Total          Pais
# 0    NaN    1.0     2.0      3     Argentina
# 1    NaN    2.0     2.0      4       Armenia
# 2   17.0    7.0    22.0     46     Australia
# 3    1.0    1.0     5.0      7       Austria
# 4    NaN    3.0     4.0      7    Azerbaijan
# ..   ...    ...     ...    ...           ...
# 88   NaN    1.0     NaN      1  Turkmenistan
# 89   2.0    1.0     1.0      4        Uganda
# 90   1.0    6.0    12.0     19       Ukraine
# 91   3.0    NaN     2.0      5    Uzbekistan
# 92   1.0    3.0     NaN      4     Venezuela
#
# [93 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     Oro  Plata  Bronce  Total        Pais
# 0   NaN    1.0     2.0      3   Argentina
# 1   NaN    2.0     2.0      4     Armenia
# 2  17.0    7.0    22.0     46   Australia
# 3   1.0    1.0     5.0      7     Austria
# 4   NaN    3.0     4.0      7  Azerbaijan

# %%
df.tail()
# Out:
#     Oro  Plata  Bronce  Total          Pais
# 88  NaN    1.0     NaN      1  Turkmenistan
# 89  2.0    1.0     1.0      4        Uganda
# 90  1.0    6.0    12.0     19       Ukraine
# 91  3.0    NaN     2.0      5    Uzbekistan
# 92  1.0    3.0     NaN      4     Venezuela

# %%
df.shape
# Out:
# (93, 5)

# %%
df.columns
# Out:
# Index(['Oro', 'Plata', 'Bronce', 'Total', 'Pais'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Oro     65 non-null     float64
#  1   Plata   69 non-null     float64
#  2   Bronce  76 non-null     float64
#  3   Total   93 non-null     int64
#  4   Pais    93 non-null     object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#              Oro      Plata     Bronce       Total
# count  65.000000  69.000000  76.000000   93.000000
# mean    4.400000   4.768116   4.934211   10.548387
# std     7.633806   7.276362   6.261705   18.897617
# min     1.000000   1.000000   1.000000    1.000000
# 25%     1.000000   1.000000   1.000000    2.000000
# 50%     2.000000   2.000000   2.000000    4.000000
# 75%     3.000000   5.000000   5.250000    8.000000
# max    39.000000  41.000000  33.000000  113.000000

# %%
df.isnull().sum()
# Out:
# Oro       28
# Plata     24
# Bronce    17
# Total      0
# Pais       0
# dtype: int64

# %%
dfLimpiar=df.dropna()
dfLimpiar
# Out:
#      Oro  Plata  Bronce  Total                        Pais
# 2   17.0    7.0    22.0     46                   Australia
# 3    1.0    1.0     5.0      7                     Austria
# 7    1.0    3.0     3.0      7                     Belarus
# 8    3.0    1.0     3.0      7                     Belgium
# 11   7.0    6.0     8.0     21                      Brazil
# 12   3.0    1.0     2.0      6                    Bulgaria
# 14   7.0    6.0    11.0     24                      Canada
# 15   2.0    4.0     6.0     12              Chinese Taipei
# 17   3.0    3.0     2.0      8                     Croatia
# 19   7.0    3.0     5.0     15                        Cuba
# 20   4.0    4.0     3.0     11              Czech Republic
# 21   3.0    4.0     4.0     11                     Denmark
# 24   1.0    1.0     4.0      6                       Egypt
# 25  39.0   41.0    33.0    113   Estados Unidos de America
# 27   1.0    1.0     2.0      4                    Ethiopia
# ...

# %%
dfRellenar=df.fillna({"Oro":0, "Plata":0, "Bronce":0})
dfRellenar
# Out:
#      Oro  Plata  Bronce  Total          Pais
# 0    0.0    1.0     2.0      3     Argentina
# 1    0.0    2.0     2.0      4       Armenia
# 2   17.0    7.0    22.0     46     Australia
# 3    1.0    1.0     5.0      7       Austria
# 4    0.0    3.0     4.0      7    Azerbaijan
# ..   ...    ...     ...    ...           ...
# 88   0.0    1.0     0.0      1  Turkmenistan
# 89   2.0    1.0     1.0      4        Uganda
# 90   1.0    6.0    12.0     19       Ukraine
# 91   3.0    0.0     2.0      5    Uzbekistan
# 92   1.0    3.0     0.0      4     Venezuela
#
# [93 rows x 5 columns]

# %%
serie=df["Pais"]
serie
# Out:
# 0        Argentina
# 1          Armenia
# 2        Australia
# 3          Austria
# 4       Azerbaijan
#           ...
# 88    Turkmenistan
# 89          Uganda
# 90         Ukraine
# 91      Uzbekistan
# 92       Venezuela
# Name: Pais, Length: 93, dtype: object

# %%
serie2=dfRellenar["Oro"]
serie2
# Out:
# 0      0.0
# 1      0.0
# 2     17.0
# 3      1.0
# 4      0.0
#       ...
# 88     0.0
# 89     2.0
# 90     1.0
# 91     3.0
# 92     1.0
# Name: Oro, Length: 93, dtype: float64

# %%
serie2.sort_values(ascending=True)
serie2
print(serie2.sort_values(ascending=False))
print(serie2)
# Out:
# 25    39.0
# 72    38.0
# 46    27.0
# 34    22.0
# 2     17.0
#       ...
# 36     0.0
# 33     0.0
# 71     0.0
# 51     0.0
# 0      0.0
# Name: Oro, Length: 93, dtype: float64
# 0      0.0
# 1      0.0
# 2     17.0
# 3      1.0
# 4      0.0
#       ...
# 88     0.0
# 89     2.0
# 90     1.0
# 91     3.0
# 92     1.0
# Name: Oro, Length: 93, dtype: float64

# %%
dir(serie)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
filtro=df["Total"]>10
filtrado=df[filtro]
filtrado
# Out:
#      Oro  Plata  Bronce  Total                        Pais
# 2   17.0    7.0    22.0     46                   Australia
# 11   7.0    6.0     8.0     21                      Brazil
# 14   7.0    6.0    11.0     24                      Canada
# 15   2.0    4.0     6.0     12              Chinese Taipei
# 19   7.0    3.0     5.0     15                        Cuba
# 20   4.0    4.0     3.0     11              Czech Republic
# 21   3.0    4.0     4.0     11                     Denmark
# 25  39.0   41.0    33.0    113   Estados Unidos de America
# 30   1.0   12.0    11.0     33                      France
# 32   1.0   11.0    16.0     37                     Germany
# 34  22.0   21.0    22.0     65                Gran Bretana
# 46  27.0   14.0    17.0     58                       Japon
# 60   1.0   12.0    14.0     36                 Netherlands
# 66   4.0    5.0     5.0     14                      Poland
# 72  38.0   32.0    18.0     88  Republica Popular de China
# ...

# %%
filtro2=df["Pais"].str.contains("M")
filtrar=df[filtro2]
filtrar
# Out:
#     Oro  Plata  Bronce  Total                 Pais
# 55  NaN    1.0     1.0      2             Malaysia
# 56  NaN    NaN     4.0      4               Mexico
# 57  NaN    1.0     3.0      4             Mongolia
# 58  1.0    NaN     NaN      1              Morocco
# 63  NaN    1.0     NaN      1      North Macedonia
# 71  NaN    NaN     1.0      1  Republic of Moldova
# 75  NaN    1.0     2.0      3           San Marino

# %%
promedio=dfRellenar["Total"].mean()
print(f"El promedio de medallas es: {promedio}")
# Out:
# El promedio de medallas es: 10.548387096774194

# %%
total=dfRellenar["Total"].sum()
print(f"El total de medallas es: {total}")
# Out:
# El total de medallas es: 981

# %%
totalOro=dfRellenar["Oro"].sum()
print(f"El total de medallas de oro es: {totalOro}")
# Out:
# El total de medallas de oro es: 286.0

# %%
totalPlata=dfRellenar["Plata"].sum()
print(f"El total de medallas de plata es: {totalPlata}")
# Out:
# El total de medallas de plata es: 329.0

# %%
totalBronce=dfRellenar["Bronce"].sum()
print(f"El total de medallas de bronce es: {totalBronce}")
# Out:
# El total de medallas de bronce es: 375.0

# %%
maximo=dfRellenar["Total"].max()
print(f"El maximo de medallas es: {maximo}")
# Out:
# El maximo de medallas es: 113

# %%
minimo=dfRellenar["Total"].min()
print(f"El minimo de medallas es: {minimo}")
# Out:
# El minimo de medallas es: 1

# %%
top3=dfRellenar.sort_values(by="Total", ascending=False).head(3)
print("Los 3 paises con mas medallas")
print(top3[["Pais", "Total"]])
# Out:
# Los 3 paises con mas medallas
#                           Pais  Total
# 25   Estados Unidos de America    113
# 72  Republica Popular de China     88
# 73                         ROC     71

# %%
mas10=dfRellenar[df["Total"]>10]
print("Paises con mas de 10 medallas")
print(mas10[["Pais", "Total"]])
# Out:
# Paises con mas de 10 medallas
#                           Pais  Total
# 2                    Australia     46
# 11                      Brazil     21
# 14                      Canada     24
# 15              Chinese Taipei     12
# 19                        Cuba     15
# 20              Czech Republic     11
# 21                     Denmark     11
# 25   Estados Unidos de America    113
# 30                      France     33
# 32                     Germany     37
# 34                Gran Bretana     65
# 46                       Japon     58
# 60                 Netherlands     36
# 66                      Poland     14
# 72  Republica Popular de China     88
# 73                         ROC     71
# 81                       Spain     17
# 83                 Switzerland     13
# 87                      Turkey     13
# 90                     Ukraine     19
